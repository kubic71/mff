# %%
from plot import *
plot_file("out/t-sequential-std", "sequential-std", "Sequential test - standard splay")
#plot_file("out/t-sequential-naive", "sequential-naive")
plt.show()
# Out:
# &lt;Figure size 1080x720 with 1 Axes&gt;

# %%
plot_file("out/t-random-std", "random-std")
plot_file("out/t-random-naive", "random-naive")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# &lt;ipython-input-2-cf4e18459a30&gt; in &lt;module&gt;
# ----&gt; 1 plot_file(&quot;out/t-random-std&quot;, &quot;random-std&quot;)
#       2 plot_file(&quot;out/t-random-naive&quot;, &quot;random-naive&quot;)
#
# TypeError: plot_file() missing 1 required positional argument: &#39;title&#39;

# %%
plot_file_subset("out/t-subset-naive", "subset-naive")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# &lt;ipython-input-3-dea800565ed5&gt; in &lt;module&gt;
# ----&gt; 1 plot_file_subset(&quot;out/t-subset-naive&quot;, &quot;subset-naive&quot;)
#
# ~/mff/2020-zs/datovky/hw/03-splay_experiment/plot.py in plot_file_subset(logfile, label)
#      36     rotations = []
#      37     k = None
# ---&gt; 38     with open(logfile, &quot;r&quot;) as f:
#      39         for line in f.read().strip().split(&quot;\n&quot;) + [&quot;0 0 0&quot;]:
#      40             line = line.split()
#
# FileNotFoundError: [Errno 2] No such file or directory: &#39;out/t-subset-naive&#39;

# %%
plot_file_subset("out/t-subset-std", "subset-std")
# Out:
# &lt;Figure size 1080x720 with 1 Axes&gt;
